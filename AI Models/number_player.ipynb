# %%
import os
import json
import shutil
from PIL import Image
from tqdm import tqdm

# ---------- user params (عدل المسارات لو عندك مسارات مختلفة) ----------
train_root = "Jersey number data and labels/jersey-2023/train/images"   # فولدر train فيه فولدرات 0,1,2...
train_json = "Jersey number data and labels/jersey-2023/train/train_gt.json"

val_root = "Jersey number data and labels/jersey-2023/test/images"      # فولدر val/test
val_json = "Jersey number data and labels/jersey-2023/test/test_gt.json"

output_dir = "yolo_dataset"                # الناتج هيبقى هنا
include_unknown = False                    # لو عايز تضيف -1 كـ class غير مفعل الآن
# -----------------------------------------------------------------------

os.makedirs(output_dir, exist_ok=True)

# --- Load mappings ---
def load_json_safe(p):
    if os.path.exists(p):
        with open(p, "r") as f:
            return json.load(f)
    return {}

train_map = load_json_safe(train_json)
val_map = load_json_safe(val_json)

# اجمع كل الأرقام الفريدة (ما بنضم -1 إلا لو اخترت include_unknown)
all_nums = set()
for m in (train_map, val_map):
    for k, v in m.items():
        if v == -1 and not include_unknown:
            continue
        all_nums.add(v)

if -1 in all_nums and not include_unknown:
    all_nums.remove(-1)

jersey_numbers = sorted(all_nums)
num_to_classid = {num: idx for idx, num in enumerate(jersey_numbers)}

print("Found jersey numbers (num -> class_id):")
print(num_to_classid)

# --- prepare output folders ---
for split in ["train", "val"]:
    os.makedirs(os.path.join(output_dir, split, "images"), exist_ok=True)
    os.makedirs(os.path.join(output_dir, split, "labels"), exist_ok=True)

# --- helper to convert a split ---
def convert_split(split_name, root_dir, json_map):
    print(f"\nConverting split: {split_name}  -- root: {root_dir}")
    missing_folders = 0
    converted = 0

    for folder, jersey_num in tqdm(json_map.items(), desc=f"Folders in {split_name}"):
        # تجاهل -1 لو مش عايز تضيفها
        if jersey_num == -1 and not include_unknown:
            continue

        if jersey_num not in num_to_classid:
            # لو فيه رقم جديد وغير متوقع (نادر) نعبر عنه
            print(f"Warning: jersey number {jersey_num} not in mapping; skipping.")
            continue

        class_id = num_to_classid[jersey_num]
        folder_path = os.path.join(root_dir, folder)
        if not os.path.exists(folder_path):
            missing_folders += 1
            continue

        for img_file in os.listdir(folder_path):
            if not img_file.lower().endswith((".jpg", ".jpeg", ".png")):
                continue

            src_img = os.path.join(folder_path, img_file)
            # اسم جديد للصورة عشان متعارضاش: folder_img.jpg
            new_img_name = f"{folder}_{img_file}"
            dst_img = os.path.join(output_dir, split_name, "images", new_img_name)
            shutil.copy2(src_img, dst_img)

            # نستخدم bbox = full image (x_center=0.5 y_center=0.5 w=1 h=1)
            # لو عندك bounding boxes دقيقة لاحقًا، ممكن تحطها هنا:
            x_center, y_center, w_norm, h_norm = 0.5, 0.5, 1.0, 1.0

            label_name = os.path.splitext(new_img_name)[0] + ".txt"
            dst_lbl = os.path.join(output_dir, split_name, "labels", label_name)
            with open(dst_lbl, "w") as f:
                f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {w_norm:.6f} {h_norm:.6f}\n")

            converted += 1

    print(f"Converted {converted} images for {split_name}. Missing folders: {missing_folders}")

# Convert both splits
convert_split("train", train_root, train_map)
convert_split("val", val_root, val_map)

# --- write class_map.json and jersey.yaml ---
class_map_path = os.path.join(output_dir, "class_map.json")
with open(class_map_path, "w") as f:
    json.dump(num_to_classid, f, indent=2, ensure_ascii=False)

# prepare names list as strings (sorted by class_id)
names_ordered = [str(n) for n in jersey_numbers]

yaml_content = {
    "train": os.path.join(output_dir, "train", "images"),
    "val": os.path.join(output_dir, "val", "images"),
    "nc": len(names_ordered),
    "names": names_ordered
}

# save jersey.yaml
import yaml
yaml_path = os.path.join(output_dir, "jersey.yaml")
with open(yaml_path, "w") as f:
    yaml.dump(yaml_content, f, allow_unicode=True)

print("\n✅ Done.")
print(f"- YOLO dataset root: {output_dir}")
print(f"- class map saved to: {class_map_path}")
print(f"- yaml file saved to: {yaml_path}")
print(f"- number of classes (nc): {yaml_content['nc']}")
# Out:
# Found jersey numbers (num -> class_id):
# {1: 0, 2: 1, 3: 2, 4: 3, 5: 4, 6: 5, 7: 6, 8: 7, 9: 8, 10: 9, 11: 10, 12: 11, 13: 12, 14: 13, 15: 14, 16: 15, 17: 16, 18: 17, 19: 18, 20: 19, 21: 20, 22: 21, 23: 22, 24: 23, 25: 24, 26: 25, 27: 26, 28: 27, 29: 28, 30: 29, 31: 30, 32: 31, 33: 32, 34: 33, 35: 34, 36: 35, 38: 36, 40: 37, 43: 38, 44: 39, 45: 40, 50: 41, 53: 42, 55: 43, 56: 44, 59: 45, 60: 46, 62: 47, 69: 48, 75: 49, 76: 50, 78: 51, 93: 52, 99: 53}
#
# Converting split: train  -- root: Jersey number data and labels/jersey-2023/train/images
# Folders in train: 100%|██████████| 1427/1427 [57:59<00:00,  2.44s/it]
# Converted 560744 images for train. Missing folders: 0
#
# Converting split: val  -- root: Jersey number data and labels/jersey-2023/test/images
# Folders in val: 100%|██████████| 1211/1211 [36:16<00:00,  1.80s/it]
# Converted 434457 images for val. Missing folders: 0
#
# ✅ Done.
# - YOLO dataset root: yolo_dataset
# - class map saved to: yolo_dataset\class_map.json
# - yaml file saved to: yolo_dataset\jersey.yaml
# - number of classes (nc): 54

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")  
model.train(data="yolo_dataset/jersey.yaml", epochs=50, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.199  Python-3.13.7 torch-2.8.0+cpu CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo_dataset/jersey.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\offside\runs\detect\train6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=54
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    441202  ultralytics.nn.modules.head.Detect           [54, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,600,370 parameters, 2,600,354 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 24.841.8 ms, read: 0.00.0 MB/s, size: 1.5 KB)
# train: Scanning D:\offside\yolo_dataset\train\labels... 553246 images, 0 backgrounds, 7498 corrupt: 100% ━━━━━━━━━━━━ 560744/560744 245.7it/s 38:02<0.0ss5
# train: D:\offside\yolo_dataset\train\images\1026_1026_1.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_10.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_100.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_101.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_102.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_103.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_104.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_105.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_106.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_107.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_108.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_109.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_11.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_110.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_111.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_112.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_113.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_114.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_115.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_116.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_117.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_118.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_119.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_12.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_120.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_121.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_122.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_123.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_124.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_125.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_126.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_127.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_128.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_129.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_13.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_130.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_131.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_132.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_133.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_134.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_135.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_136.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_137.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_138.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_139.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_14.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_140.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_141.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_142.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_143.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_144.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_145.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_146.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_147.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_148.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_149.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_15.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_150.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_151.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_152.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_153.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_154.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_155.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_156.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_157.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_16.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_163.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_164.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_165.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_17.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_18.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_19.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_2.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_20.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_3.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_4.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_5.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_6.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_7.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_8.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_81.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_82.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_83.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_84.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_85.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_86.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_87.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_88.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_89.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_9.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_90.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_91.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_92.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_93.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_94.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_95.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_96.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_97.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_98.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1026_1026_99.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_324.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_325.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_326.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_327.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_328.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_329.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_330.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_331.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\102_102_332.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_131.jpg: ignoring corrupt image/label: image size (10, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_132.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_133.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_134.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_203.jpg: ignoring corrupt image/label: image size (11, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_246.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_247.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_248.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_249.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_250.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_251.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_275.jpg: ignoring corrupt image/label: image size (9, 18) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_276.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_277.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_278.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_279.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_280.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_281.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_282.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_283.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_284.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_285.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_286.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_287.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_288.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_289.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_290.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_291.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_292.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_293.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_294.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_295.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_296.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_297.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_298.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_299.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_300.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_301.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_302.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_303.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_304.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_305.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_306.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_307.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_308.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_309.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_310.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_311.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_312.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_313.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_314.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_315.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_316.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_317.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_318.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_319.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_320.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_321.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_322.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_323.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_324.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_325.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_326.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_327.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_328.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_329.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_330.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_331.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_332.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_333.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_334.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_335.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_336.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_337.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_338.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_339.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_340.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_341.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_342.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_343.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_344.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_345.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_346.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_347.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_426.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_545.jpg: ignoring corrupt image/label: image size (8, 6) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_546.jpg: ignoring corrupt image/label: image size (9, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_615.jpg: ignoring corrupt image/label: image size (12, 6) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_616.jpg: ignoring corrupt image/label: image size (11, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_617.jpg: ignoring corrupt image/label: image size (9, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_618.jpg: ignoring corrupt image/label: image size (9, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_619.jpg: ignoring corrupt image/label: image size (10, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_620.jpg: ignoring corrupt image/label: image size (10, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_621.jpg: ignoring corrupt image/label: image size (13, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_622.jpg: ignoring corrupt image/label: image size (13, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_623.jpg: ignoring corrupt image/label: image size (14, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_624.jpg: ignoring corrupt image/label: image size (14, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_625.jpg: ignoring corrupt image/label: image size (14, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1033_1033_626.jpg: ignoring corrupt image/label: image size (14, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1039_1039_110.jpg: ignoring corrupt image/label: image size (50, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1039_1039_111.jpg: ignoring corrupt image/label: image size (50, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\104_104_607.jpg: ignoring corrupt image/label: image size (46, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1068_1068_375.jpg: ignoring corrupt image/label: image size (150, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_731.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_732.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_733.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_734.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_735.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_736.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_737.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_738.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_739.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_740.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_741.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_742.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_743.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_744.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_745.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_746.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_747.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_748.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_749.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1077_1077_750.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1078_1078_266.jpg: ignoring corrupt image/label: image size (69, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_1.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_2.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_3.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_4.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_5.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_6.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_670.jpg: ignoring corrupt image/label: image size (9, 26) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_671.jpg: ignoring corrupt image/label: image size (9, 26) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_700.jpg: ignoring corrupt image/label: image size (12, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1080_1080_701.jpg: ignoring corrupt image/label: image size (12, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_172.jpg: ignoring corrupt image/label: image size (8, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_44.jpg: ignoring corrupt image/label: image size (57, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_45.jpg: ignoring corrupt image/label: image size (54, 5) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_456.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_46.jpg: ignoring corrupt image/label: image size (42, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_54.jpg: ignoring corrupt image/label: image size (58, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_73.jpg: ignoring corrupt image/label: image size (54, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_738.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_74.jpg: ignoring corrupt image/label: image size (39, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_75.jpg: ignoring corrupt image/label: image size (11, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_76.jpg: ignoring corrupt image/label: image size (5, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1087_1087_77.jpg: ignoring corrupt image/label: image size (5, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1089_1089_470.jpg: ignoring corrupt image/label: image size (52, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1089_1089_471.jpg: ignoring corrupt image/label: image size (52, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1089_1089_517.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1089_1089_518.jpg: ignoring corrupt image/label: image size (12, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1094_1094_470.jpg: ignoring corrupt image/label: image size (94, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1097_1097_229.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1097_1097_685.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1101_1101_245.jpg: ignoring corrupt image/label: image size (14, 6) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1101_1101_246.jpg: ignoring corrupt image/label: image size (15, 6) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1104_1104_317.jpg: ignoring corrupt image/label: image size (57, 5) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1104_1104_318.jpg: ignoring corrupt image/label: image size (57, 5) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1106_1106_318.jpg: ignoring corrupt image/label: image size (80, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1110_1110_284.jpg: ignoring corrupt image/label: image size (58, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1110_1110_285.jpg: ignoring corrupt image/label: image size (58, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1116_1116_289.jpg: ignoring corrupt image/label: image size (50, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1116_1116_290.jpg: ignoring corrupt image/label: image size (50, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_191.jpg: ignoring corrupt image/label: image size (17, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_192.jpg: ignoring corrupt image/label: image size (17, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_326.jpg: ignoring corrupt image/label: image size (13, 5) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_327.jpg: ignoring corrupt image/label: image size (11, 5) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_328.jpg: ignoring corrupt image/label: image size (9, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_329.jpg: ignoring corrupt image/label: image size (3, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_330.jpg: ignoring corrupt image/label: image size (4, 5) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_380.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_381.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_383.jpg: ignoring corrupt image/label: image size (9, 19) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_384.jpg: ignoring corrupt image/label: image size (8, 18) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_385.jpg: ignoring corrupt image/label: image size (8, 18) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_386.jpg: ignoring corrupt image/label: image size (8, 18) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_387.jpg: ignoring corrupt image/label: image size (9, 17) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_388.jpg: ignoring corrupt image/label: image size (9, 16) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_389.jpg: ignoring corrupt image/label: image size (9, 16) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_391.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_392.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_393.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_396.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_397.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_398.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_399.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_400.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_401.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_402.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_403.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_404.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_405.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_406.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_407.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_408.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_409.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_423.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_516.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_517.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_518.jpg: ignoring corrupt image/label: image size (10, 8) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_519.jpg: ignoring corrupt image/label: image size (9, 6) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_520.jpg: ignoring corrupt image/label: image size (9, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_521.jpg: ignoring corrupt image/label: image size (8, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_528.jpg: ignoring corrupt image/label: image size (8, 4) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_529.jpg: ignoring corrupt image/label: image size (10, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_530.jpg: ignoring corrupt image/label: image size (10, 7) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_531.jpg: ignoring corrupt image/label: image size (14, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_667.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1118_1118_668.jpg: ignoring corrupt image/label: image size (8, 12) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1127_1127_319.jpg: ignoring corrupt image/label: image size (60, 6) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_163.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_164.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_165.jpg: ignoring corrupt image/label: image size (8, 15) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_166.jpg: ignoring corrupt image/label: image size (8, 15) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_167.jpg: ignoring corrupt image/label: image size (9, 15) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_176.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_177.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_178.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_179.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_180.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_181.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_182.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_183.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_184.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_185.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_186.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_187.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_188.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_374.jpg: ignoring corrupt image/label: image size (12, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_375.jpg: ignoring corrupt image/label: image size (12, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_378.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_427.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_428.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_429.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_430.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_431.jpg: ignoring corrupt image/label: image size (9, 14) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_432.jpg: ignoring corrupt image/label: image size (8, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_433.jpg: ignoring corrupt image/label: image size (8, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_434.jpg: ignoring corrupt image/label: image size (8, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_435.jpg: ignoring corrupt image/label: image size (8, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_436.jpg: ignoring corrupt image/label: image size (8, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_437.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# train: D:\offside\yolo_dataset\train\images\1128_1128_438.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# ...
# val: D:\offside\yolo_dataset\val\images\939_939_57.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_58.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_59.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_6.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_60.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_61.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_62.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_63.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_64.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_65.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_66.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_67.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_68.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_69.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_7.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_70.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_71.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_72.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_73.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_74.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_75.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_76.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_77.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_78.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_79.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_8.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_80.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_81.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_82.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_83.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_84.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_85.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_86.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_87.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_88.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_89.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_9.jpg: ignoring corrupt image/label: image size (8, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_90.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_91.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_92.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_93.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_94.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_95.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_96.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_97.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_98.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\939_939_99.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_112.jpg: ignoring corrupt image/label: image size (9, 8) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_113.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_114.jpg: ignoring corrupt image/label: image size (9, 13) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_211.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_212.jpg: ignoring corrupt image/label: image size (7, 6) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_274.jpg: ignoring corrupt image/label: image size (12, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_275.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_276.jpg: ignoring corrupt image/label: image size (7, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_277.jpg: ignoring corrupt image/label: image size (8, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_278.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_294.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_328.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_329.jpg: ignoring corrupt image/label: image size (11, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_574.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_575.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_576.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_577.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_578.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_579.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_580.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_581.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_582.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_583.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_584.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_585.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_586.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_587.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_588.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_589.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_590.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_591.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_592.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_593.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_594.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_595.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_596.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_597.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_598.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_599.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_600.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_601.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_602.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_603.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_604.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_605.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_606.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_607.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_608.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_609.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_610.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_611.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_612.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_613.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_614.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_615.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_616.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_617.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_618.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_619.jpg: ignoring corrupt image/label: image size (9, 12) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_620.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_621.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_622.jpg: ignoring corrupt image/label: image size (9, 11) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_623.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_673.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_674.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_675.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_676.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_677.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_678.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_679.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_680.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_681.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_682.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_683.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_684.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_685.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_686.jpg: ignoring corrupt image/label: image size (9, 10) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_688.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_689.jpg: ignoring corrupt image/label: image size (10, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_715.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_716.jpg: ignoring corrupt image/label: image size (9, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_92.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_93.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: D:\offside\yolo_dataset\val\images\961_961_94.jpg: ignoring corrupt image/label: image size (8, 9) <10 pixels
# val: New cache created: D:\offside\yolo_dataset\val\labels.cache
# Plotting labels to D:\offside\runs\detect\train6\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\offside\runs\detect\train6
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G     0.7162       4.52       1.28         52        640: 1% ──────────── 435/34578 0.1it/s 1:08:53<98:04:110
